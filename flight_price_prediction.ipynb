# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /var/folders/jn/5hx9ymq526v78x75qss7g_ww0000gn/T/ipykernel_19193/1654069430.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('flights.csv')
df
# Out:
#       origin destination depart_time arrive_time          airliner  \
# 0        THD         SGN    19:30:00    21:30:00       VietJet Air
# 1        THD         SGN    12:55:00    14:55:00       VietJet Air
# 2        THD         SGN    15:20:00    17:20:00       VietJet Air
# 3        THD         SGN    19:30:00    21:30:00       VietJet Air
# 4        THD         SGN    12:55:00    14:55:00       VietJet Air
# ...      ...         ...         ...         ...               ...
# 11612    VDO         SGN    08:55:00    11:05:00  Vietnam Airlines
# 11613    VDO         SGN    09:50:00    12:05:00       VietJet Air
# 11614    VDO         SGN    09:50:00    12:05:00       VietJet Air
# 11615    VDO         SGN    09:50:00    12:05:00       VietJet Air
# 11616    VDO         SGN    09:50:00    12:05:00       VietJet Air
#
#        duration_min        date    price airport_origin_name  \
# 0               120  2024-06-26  1783800    Tho Xuan Airport
# 1               120  2024-06-26  1956600    Tho Xuan Airport
# 2               120  2024-06-26  1956600    Tho Xuan Airport
# 3               120  2024-06-27  1783800    Tho Xuan Airport
# 4               120  2024-06-27  1956600    Tho Xuan Airport
# ...             ...         ...      ...                 ...
# 11612           130  2024-07-06  1940000     Van Don Airport
# 11613           135  2024-07-07  2084600     Van Don Airport
# 11614           135  2024-07-10  2084600     Van Don Airport
# 11615           135  2024-07-12  2084600     Van Don Airport
# 11616           135  2024-07-14  2084600     Van Don Airport
#
#         airport_destination_name
# 0      Tan Son Nhat Intl Airport
# 1      Tan Son Nhat Intl Airport
# 2      Tan Son Nhat Intl Airport
# 3      Tan Son Nhat Intl Airport
# 4      Tan Son Nhat Intl Airport
# ...                          ...
# 11612  Tan Son Nhat Intl Airport
# 11613  Tan Son Nhat Intl Airport
# 11614  Tan Son Nhat Intl Airport
# 11615  Tan Son Nhat Intl Airport
# 11616  Tan Son Nhat Intl Airport
#
# [11617 rows x 10 columns]

# %%
airline = df['airliner']
airline = pd.get_dummies(airline)
airline.head()
# Out:
#    Bamboo Airways  VietJet Air  Vietnam Airlines  Vietravel Airlines
# 0           False         True             False               False
# 1           False         True             False               False
# 2           False         True             False               False
# 3           False         True             False               False
# 4           False         True             False               False

# %%
list1 = ['origin', 'destination']
for l in list1:
    print(df[[l]].value_counts(),'\n')
# Out:
# origin
# SGN       3467
# HAN       2961
# DAD       1700
# CXR        579
# PQC        502
# HPH        359
# VII        316
# DLI        275
# HUI        269
# UIH        240
# VCS        206
# VCA        171
# BMV        152
# PXU         86
# THD         84
# VCL         84
# VDH         63
# TBB         40
# DIN         32
# CAH         14
# VDO         13
# VKG          4
# Name: count, dtype: int64
#
# destination
# SGN            3688
# HAN            3021
# DAD            1701
# CXR             574
# PQC             498
# VII             326
# HPH             315
# HUI             299
# DLI             261
# VCS             195
# VCA             172
# BMV             163
# PXU              82
# THD              80
# VCL              79
# VDH              59
# TBB              39
# DIN              33
# CAH              14
# VDO              13
# VKG               5
# Name: count, dtype: int64

# %%
df = pd.get_dummies(data = df, columns = list1)
df
# Out:
#       depart_time arrive_time          airliner  duration_min        date  \
# 0        19:30:00    21:30:00       VietJet Air           120  2024-06-26
# 1        12:55:00    14:55:00       VietJet Air           120  2024-06-26
# 2        15:20:00    17:20:00       VietJet Air           120  2024-06-26
# 3        19:30:00    21:30:00       VietJet Air           120  2024-06-27
# 4        12:55:00    14:55:00       VietJet Air           120  2024-06-27
# ...           ...         ...               ...           ...         ...
# 11612    08:55:00    11:05:00  Vietnam Airlines           130  2024-07-06
# 11613    09:50:00    12:05:00       VietJet Air           135  2024-07-07
# 11614    09:50:00    12:05:00       VietJet Air           135  2024-07-10
# 11615    09:50:00    12:05:00       VietJet Air           135  2024-07-12
# 11616    09:50:00    12:05:00       VietJet Air           135  2024-07-14
#
#          price airport_origin_name   airport_destination_name  origin_BMV  \
# 0      1783800    Tho Xuan Airport  Tan Son Nhat Intl Airport       False
# 1      1956600    Tho Xuan Airport  Tan Son Nhat Intl Airport       False
# 2      1956600    Tho Xuan Airport  Tan Son Nhat Intl Airport       False
# 3      1783800    Tho Xuan Airport  Tan Son Nhat Intl Airport       False
# 4      1956600    Tho Xuan Airport  Tan Son Nhat Intl Airport       False
# ...        ...                 ...                        ...         ...
# 11612  1940000     Van Don Airport  Tan Son Nhat Intl Airport       False
# 11613  2084600     Van Don Airport  Tan Son Nhat Intl Airport       False
# 11614  2084600     Van Don Airport  Tan Son Nhat Intl Airport       False
# 11615  2084600     Van Don Airport  Tan Son Nhat Intl Airport       False
# 11616  2084600     Van Don Airport  Tan Son Nhat Intl Airport       False
#
#        origin_CAH  ...  destination_SGN  destination_TBB  destination_THD  \
# 0           False  ...             True            False            False
# 1           False  ...             True            False            False
# 2           False  ...             True            False            False
# 3           False  ...             True            False            False
# 4           False  ...             True            False            False
# ...           ...  ...              ...              ...              ...
# 11612       False  ...             True            False            False
# 11613       False  ...             True            False            False
# 11614       False  ...             True            False            False
# 11615       False  ...             True            False            False
# 11616       False  ...             True            False            False
#
#        destination_VCA  destination_VCL  destination_VCS  destination_VDH  \
# 0                False            False            False            False
# 1                False            False            False            False
# 2                False            False            False            False
# 3                False            False            False            False
# 4                False            False            False            False
# ...                ...              ...              ...              ...
# 11612            False            False            False            False
# 11613            False            False            False            False
# 11614            False            False            False            False
# 11615            False            False            False            False
# 11616            False            False            False            False
#
#        destination_VDO  destination_VII  destination_VKG
# 0                False            False            False
# 1                False            False            False
# 2                False            False            False
# 3                False            False            False
# 4                False            False            False
# ...                ...              ...              ...
# 11612            False            False            False
# 11613            False            False            False
# 11614            False            False            False
# 11615            False            False            False
# 11616            False            False            False
#
# [11617 rows x 51 columns]

# %%
df = pd.concat([df, airline], axis = 1)
df.drop(['airliner', 'airport_origin_name', 'airport_destination_name'], axis = 1, inplace = True)
df
# Out:
#       depart_time arrive_time  duration_min        date    price  origin_BMV  \
# 0        19:30:00    21:30:00           120  2024-06-26  1783800       False
# 1        12:55:00    14:55:00           120  2024-06-26  1956600       False
# 2        15:20:00    17:20:00           120  2024-06-26  1956600       False
# 3        19:30:00    21:30:00           120  2024-06-27  1783800       False
# 4        12:55:00    14:55:00           120  2024-06-27  1956600       False
# ...           ...         ...           ...         ...      ...         ...
# 11612    08:55:00    11:05:00           130  2024-07-06  1940000       False
# 11613    09:50:00    12:05:00           135  2024-07-07  2084600       False
# 11614    09:50:00    12:05:00           135  2024-07-10  2084600       False
# 11615    09:50:00    12:05:00           135  2024-07-12  2084600       False
# 11616    09:50:00    12:05:00           135  2024-07-14  2084600       False
#
#        origin_CAH  origin_CXR  origin_DAD  origin_DIN  ...  destination_VCL  \
# 0           False       False       False       False  ...            False
# 1           False       False       False       False  ...            False
# 2           False       False       False       False  ...            False
# 3           False       False       False       False  ...            False
# 4           False       False       False       False  ...            False
# ...           ...         ...         ...         ...  ...              ...
# 11612       False       False       False       False  ...            False
# 11613       False       False       False       False  ...            False
# 11614       False       False       False       False  ...            False
# 11615       False       False       False       False  ...            False
# 11616       False       False       False       False  ...            False
#
#        destination_VCS  destination_VDH  destination_VDO  destination_VII  \
# 0                False            False            False            False
# 1                False            False            False            False
# 2                False            False            False            False
# 3                False            False            False            False
# 4                False            False            False            False
# ...                ...              ...              ...              ...
# 11612            False            False            False            False
# 11613            False            False            False            False
# 11614            False            False            False            False
# 11615            False            False            False            False
# 11616            False            False            False            False
#
#        destination_VKG  Bamboo Airways  VietJet Air  Vietnam Airlines  \
# 0                False           False         True             False
# 1                False           False         True             False
# 2                False           False         True             False
# 3                False           False         True             False
# 4                False           False         True             False
# ...                ...             ...          ...               ...
# 11612            False           False        False              True
# 11613            False           False         True             False
# 11614            False           False         True             False
# 11615            False           False         True             False
# 11616            False           False         True             False
#
#        Vietravel Airlines
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 11612               False
# 11613               False
# 11614               False
# 11615               False
# 11616               False
#
# [11617 rows x 52 columns]

# %%
df['day'] = pd.to_datetime(df['date']).dt.day
df['month'] = pd.to_datetime(df['date']).dt.month
df.drop(['date'], axis = 1, inplace = True)

# %%
df['depart_hr'] = pd.to_datetime(df['depart_time'].astype(str)).dt.hour
df['depart_min'] = pd.to_datetime(df['depart_time'].astype(str)).dt.minute
df['arr_hr'] = pd.to_datetime(df['arrive_time'].astype(str)).dt.hour
df['arr_min'] = pd.to_datetime(df['arrive_time'].astype(str)).dt.minute
df.drop(['depart_time', 'arrive_time', 'duration_min'], axis = 1, inplace = True)
# Out:
# /var/folders/jn/5hx9ymq526v78x75qss7g_ww0000gn/T/ipykernel_19193/3220238012.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['depart_hr'] = pd.to_datetime(df['depart_time'].astype(str)).dt.hour
# /var/folders/jn/5hx9ymq526v78x75qss7g_ww0000gn/T/ipykernel_19193/3220238012.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['depart_min'] = pd.to_datetime(df['depart_time'].astype(str)).dt.minute
# /var/folders/jn/5hx9ymq526v78x75qss7g_ww0000gn/T/ipykernel_19193/3220238012.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['arr_hr'] = pd.to_datetime(df['arrive_time'].astype(str)).dt.hour
# /var/folders/jn/5hx9ymq526v78x75qss7g_ww0000gn/T/ipykernel_19193/3220238012.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['arr_min'] = pd.to_datetime(df['arrive_time'].astype(str)).dt.minute

# %%
df
# Out:
#          price  origin_BMV  origin_CAH  origin_CXR  origin_DAD  origin_DIN  \
# 0      1783800       False       False       False       False       False
# 1      1956600       False       False       False       False       False
# 2      1956600       False       False       False       False       False
# 3      1783800       False       False       False       False       False
# 4      1956600       False       False       False       False       False
# ...        ...         ...         ...         ...         ...         ...
# 11612  1940000       False       False       False       False       False
# 11613  2084600       False       False       False       False       False
# 11614  2084600       False       False       False       False       False
# 11615  2084600       False       False       False       False       False
# 11616  2084600       False       False       False       False       False
#
#        origin_DLI  origin_HAN  origin_HPH  origin_HUI  ...  Bamboo Airways  \
# 0           False       False       False       False  ...           False
# 1           False       False       False       False  ...           False
# 2           False       False       False       False  ...           False
# 3           False       False       False       False  ...           False
# 4           False       False       False       False  ...           False
# ...           ...         ...         ...         ...  ...             ...
# 11612       False       False       False       False  ...           False
# 11613       False       False       False       False  ...           False
# 11614       False       False       False       False  ...           False
# 11615       False       False       False       False  ...           False
# 11616       False       False       False       False  ...           False
#
#        VietJet Air  Vietnam Airlines  Vietravel Airlines  day  month  \
# 0             True             False               False   26      6
# 1             True             False               False   26      6
# 2             True             False               False   26      6
# 3             True             False               False   27      6
# 4             True             False               False   27      6
# ...            ...               ...                 ...  ...    ...
# 11612        False              True               False    6      7
# 11613         True             False               False    7      7
# 11614         True             False               False   10      7
# 11615         True             False               False   12      7
# 11616         True             False               False   14      7
#
#        depart_hr  depart_min  arr_hr  arr_min
# 0             19          30      21       30
# 1             12          55      14       55
# 2             15          20      17       20
# 3             19          30      21       30
# 4             12          55      14       55
# ...          ...         ...     ...      ...
# 11612          8          55      11        5
# 11613          9          50      12        5
# 11614          9          50      12        5
# 11615          9          50      12        5
# 11616          9          50      12        5
#
# [11617 rows x 54 columns]

# %% [markdown]
# # <h2>Feature Selection/Importance</h2>

# %%
df.shape
# Out:
# (11617, 54)

# %%
df.columns
# Out:
# Index(['price', 'origin_BMV', 'origin_CAH', 'origin_CXR', 'origin_DAD',
#        'origin_DIN', 'origin_DLI', 'origin_HAN', 'origin_HPH', 'origin_HUI',
#        'origin_PQC', 'origin_PXU', 'origin_SGN', 'origin_TBB', 'origin_THD',
#        'origin_UIH', 'origin_VCA', 'origin_VCL', 'origin_VCS', 'origin_VDH',
#        'origin_VDO', 'origin_VII', 'origin_VKG', 'destination_BMV',
#        'destination_CAH', 'destination_CXR', 'destination_DAD',
#        'destination_DIN', 'destination_DLI', 'destination_HAN',
#        'destination_HPH', 'destination_HUI', 'destination_PQC',
#        'destination_PXU', 'destination_SGN', 'destination_TBB',
#        'destination_THD', 'destination_VCA', 'destination_VCL',
#        'destination_VCS', 'destination_VDH', 'destination_VDO',
#        'destination_VII', 'destination_VKG', 'Bamboo Airways', 'VietJet Air',
#        'Vietnam Airlines', 'Vietravel Airlines', 'day', 'month', 'depart_hr',
#        'depart_min', 'arr_hr', 'arr_min'],
#       dtype='object')

# %%
X = df.loc[:, ['origin_BMV', 'origin_CAH', 'origin_CXR', 'origin_DAD',
       'origin_DIN', 'origin_DLI', 'origin_HAN', 'origin_HPH', 'origin_HUI',
       'origin_PQC', 'origin_PXU', 'origin_SGN', 'origin_TBB', 'origin_THD',
       'origin_UIH', 'origin_VCA', 'origin_VCL', 'origin_VCS', 'origin_VDH',
       'origin_VDO', 'origin_VII', 'origin_VKG', 'destination_BMV',
       'destination_CAH', 'destination_CXR', 'destination_DAD',
       'destination_DIN', 'destination_DLI', 'destination_HAN',
       'destination_HPH', 'destination_HUI', 'destination_PQC',
       'destination_PXU', 'destination_SGN', 'destination_TBB',
       'destination_THD', 'destination_VCA', 'destination_VCL',
       'destination_VCS', 'destination_VDH', 'destination_VDO',
       'destination_VII', 'destination_VKG', 'Bamboo Airways', 'VietJet Air',
       'Vietnam Airlines', 'Vietravel Airlines', 'day', 'month', 'depart_hr',
       'depart_min', 'arr_hr', 'arr_min']]
X.head()
# Out:
#    origin_BMV  origin_CAH  origin_CXR  origin_DAD  origin_DIN  origin_DLI  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
#    origin_HAN  origin_HPH  origin_HUI  origin_PQC  ...  Bamboo Airways  \
# 0       False       False       False       False  ...           False
# 1       False       False       False       False  ...           False
# 2       False       False       False       False  ...           False
# 3       False       False       False       False  ...           False
# 4       False       False       False       False  ...           False
#
#    VietJet Air  Vietnam Airlines  Vietravel Airlines  day  month  depart_hr  \
# 0         True             False               False   26      6         19
# 1         True             False               False   26      6         12
# 2         True             False               False   26      6         15
# 3         True             False               False   27      6         19
# 4         True             False               False   27      6         12
#
#    depart_min  arr_hr  arr_min
# 0          30      21       30
# 1          55      14       55
# 2          20      17       20
# 3          30      21       30
# 4          55      14       55
#
# [5 rows x 53 columns]

# %%
y = df.iloc[:, 0]
y.head()
# Out:
# 0    1783800
# 1    1956600
# 2    1956600
# 3    1783800
# 4    1956600
# Name: price, dtype: int64

# %% [markdown]
# # <h2>Feature Selection/Importance</h2>

# %%
x = df.drop(['price'], axis =1 )
y = df['price']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data = sc.fit_transform(x)
data[0]
# Out:
# array([-0.11514226, -0.03473593, -0.2290309 , -0.41403238, -0.05255656,
#        -0.1557118 , -0.58487166, -0.17857333, -0.15396304, -0.21251869,
#        -0.08636062, -0.65222601, -0.05878032, 11.71740667, -0.14524184,
#        -0.12222813, -0.08534312, -0.13436055, -0.07384211, -0.03347093,
#        -0.1672188 , -0.01855914, -0.11929307, -0.03473593, -0.22798822,
#        -0.41417502, -0.05337375, -0.15160292, -0.59282589, -0.16694662,
#        -0.16253644, -0.21163223, -0.0843137 ,  1.46626934, -0.05803841,
#        -0.08327191, -0.12259036, -0.08274624, -0.13066108, -0.07144711,
#        -0.03347093, -0.16991926, -0.02075064, -0.24305468,  1.09287281,
#        -0.92763467, -0.16337146,  1.41648927, -1.79010834,  0.91402959,
#         0.21004237,  1.18106828,  0.19432359])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 123)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((8131, 53), (3486, 53), (8131,), (3486,))

# %% [markdown]
# # <h2><center>ExtraTreesRegressor Model</center></h2>

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor()
model.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
from sklearn.metrics import r2_score, mean_squared_error

def metrics(y_true, y_pred):
    print(f'RMSE:', mean_squared_error(y_test, y_pred)**0.5)
    print(f'R2 score:', r2_score(y_test, y_pred))
def accuracy(y_true, y_pred):
    errors = abs(y_pred - y_true)
    mape = 100 * np.mean(errors / y_true)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))

# %%
y_pred = model.predict(X_test)

# %%
metrics(y_test, y_pred)
# Out:
# RMSE: 285964.53848609613
# R2 score: 0.7090084670378316

# %%
accuracy(y_test, y_pred)
# Out:
# Model Performance
# Average Error: 149874.3379 degrees.
# Accuracy = 92.45%.

# %% [markdown]
# # <h2><center>Linear Regression Model</center></h2>

# %%
from sklearn.linear_model import LinearRegression

linearmodel = LinearRegression()
linearmodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_linear_pred = linearmodel.predict(X_test)

# %%
metrics(y_test, y_linear_pred)
# Out:
# RMSE: 437634.91554063564
# R2 score: 0.31847794024673515

# %%
accuracy(y_test, y_linear_pred)
# Out:
# Model Performance
# Average Error: 296404.8789 degrees.
# Accuracy = 83.49%.

# %%
sns.distplot(y_test-y_linear_pred)
plt.show()
# Out:
# /var/folders/jn/5hx9ymq526v78x75qss7g_ww0000gn/T/ipykernel_19193/165930020.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_linear_pred)

# %% [markdown]
# # <h2><center>Random Forest Model</center></h2>

# %%
from sklearn.ensemble import RandomForestRegressor
randomforest_model = RandomForestRegressor(n_estimators=100, min_samples_split = 3)
randomforest_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=3)

# %%
pred_rf = randomforest_model.predict(X_test)

# %%
metrics(y_test, pred_rf)
# Out:
# RMSE: 251498.7149614255
# R2 score: 0.7749248589200912

# %%
accuracy(y_test, pred_rf)
# Out:
# Model Performance
# Average Error: 135749.0604 degrees.
# Accuracy = 93.10%.
